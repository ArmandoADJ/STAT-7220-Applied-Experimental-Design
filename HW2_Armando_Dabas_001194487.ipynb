# %% [markdown]
# <a href="https://colab.research.google.com/github/ArmandoADJ/STAT-7220-Applied-Experimental-Design/blob/Test/HW2_Armando_Dabas_001194487.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 2: Randomized Block and Latin Square Designs
# ## Dr. Austin R. Brown
# ### School of Data Science & Analytics
# ### Kennesaw State University
#
# **DUE: October 3, 2025**
#
# **PART 1 INSTRUCTIONS:** You are an educational researcher interested in comparing different methods for teaching data science to undergraduate students. There are three different methods you are interested in comparing: (1) Direct Instruction (traditional method); (2) Inquiry-Based Learning (teacher facilitates student problem solving); (3) Collaborative Learning (students working in small groups). To compare these methods, you decide to randomly recruit undergraduate data science students to be part of a workshop on hypothesis testing basics. Students will be randomly assigned to one of three workshops, where each workshop employs a different teaching method. At the end of the workshop, students will be given a 50-question quiz where their understanding of hypothesis testing will be assessed. Percentage scores on this quiz serve as the outcome of interest.
#
# However, it would be apparent that the prior level of knowledge a student possess about hypothesis testing may serve as a potential confounding variable that you would want to control for. Thus, the Prior Knowledge a given student has about hypothesis testing is categorized into "High" and "Low". The data from this experiment are contained in the `Data Science Teaching Method.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# The objective of this experiment is to test whether one of the different teaching methods yields a different result.
#
# **Question 2.** Specify the outcome variable
#
# The outcome variable or dependent variable for this study is the test score measured in %.
#
# **Question 3.** Specify the independent variable and blocking factor. What are some possible lurking variables?
#
# The independent variable is the teaching methods: Direct Instruction, Inquiry-based Learning and Collaborative learning. The blocking factor or cofounding variable is: Prior experience with hypothesis testing.
#
# Possible lurking variables: Students with prior knowledge should also be correctly devided into treatmet which if not divided into different groups could leverage the mean of a group.
#
# **Question 4.** Briefly explain why a randomized block design would be appropriate here. Similarly, explain why a completely randomized design would not be appropriate.
#
# A randomized Block design is appropiate due to a cofounding variable thats influencing both dependent and independent variable, if an student has prior knowledge it would make sense that he has a better grasp of whats taught in the class.
#
# On why a completely randomized design is not appropiate is due to the same reasons, there's a coufounding variable that might explain part of the variability in our design, that cannot be explained if a CRD would be performed.
#
# It can be said that the porpuse for using an RBD is due to the fact that we have knowledge of block that can contribute to explain the variability in the model.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# $H_0$: $\mu$ = 0 there's no difference between the means of the treatments.
#
# $H_1$: $\mu$ != 0 there's at least one treatment mean that differs.

# %%
# === COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "ArmandoADJ"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
   print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
   print("💡 Please fork the repo to your own account and update `github_username` above.")
else:
  print(f"🔗 Connected to fork at: {remote_url}")

# Set Today's Directory #

today_dir = "Assignments/HW2"
os.chdir(today_dir)
print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/ArmandoADJ/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/ArmandoADJ/STAT-7220-Applied-Experimental-Design.git
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design/Assignments/HW2

# %% [markdown]
# **Question 6.** Perform appropriate exploratory analysis, including summary statistics **and** data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# By looking at the descriptive statistic it can be assesed that there's a significant difference between the teaching methods. When plotting the teaching method in a boxplot this assumption can be confirmed.
#
# When plotting for teaching methods grouped by Prior knowledge it can be seen a marging difference between prior knowledge Low-High.
#
# These assumptions support the alternative hypothesis which says the following: $H_1$: $\mu$ != 0 there's at least one treatment mean that differs.
#
# **Question 7.** Build a two-way ANOVA model. Test the assumption of normality using **both** a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
# As the program return down below both the visual and testing method using shapiro-wilk test demonstrate evidence that the assumption of normality is met.
#
# $R^2$ = 0.988 and P-value = 0.642
#
# **Question 8.** Test the assumption of homogeneity of variance using **both** a visual method and a testing method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# When testing the for the assumption of homogeneity both visual and testing method using the B-P method supports that there's homogeinity of variance with an F-Statistic of:1.363 and a P-Value of: 0.263
#
# **Question 9.** Report the F-statistic and its associated p-value for the treatment effect. Which of our two hypotheses is more strongly supported? Why?
#
# F(3, 56) = 15.32 , p = 2.14e-07. The Hypothesis that's can be considered "strongly" support is the alternative hypothesis.
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# The Tukey's HSD post-hoc test determined that Direct teaching method differs the other teaching method with a P-value of: 0.0 for Collaborative-Direct and a P-Value of: 0.0003 for Inquiry- Direct.
#
# **Question 11.** Write a brief, contextual conclusion summarizing the results of your analyses, including potential limitations of this experiment.
#
# As it can be seen by the results shown below, at least one of the groups seems to be different: Direct Method of teaching is the factor which our anova table considered as statistically significant, when testing for tukey's HSD post-hoc it was concluded that the direct-method of teaching was the only different between the different treatments in the study. yielding a signficant lower mean for the test scores of 75%. The anova table returned the following results:
#
# F(3, 56) = 15.32 , p = 2.14e-07 , $R^2$ = 0.451
#
# The Potential limitations of this experiment is that the experiment is not accounting for the amount of hours dedicated from each student when preparing for the test and other factors that could affect student performance.

# %%
## Import Necessary Packages ##
from itertools import groupby
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd


## Import File##
path_file = "/content/STAT-7220-Applied-Experimental-Design/Assignments/HW2/Data Science Teaching Method.xlsx"
df = pd.read_excel(path_file)

##Print Columns names and first 6 rows#
df.head()

##Descriptive analysis of Teaching Methods##
print(df.groupby("Teaching_Method")["Score"].agg(["mean","std", "count"]))

##Data Visualization##
sns.boxplot(data = df, x = "Teaching_Method", y = "Score")
plt.title("Boxplot of scores grouped by teaching Methods")
plt.xlabel("Teaching Method")
plt.ylabel("Score")
plt.show()

print("\n")
sns.scatterplot(data = df, x = "Teaching_Method", y = "Score", hue = "Prior_Knowledge")
plt.title("Scatterplot of scores grouped by Teaching Methods")
plt.xlabel("Teaching Methods")
plt.ylabel("Score")
plt.show()

print("\n")

facet = sns.FacetGrid(df, col = "Teaching_Method", hue = "Teaching_Method")
facet.map(sns.histplot, "Score")
plt.show()

################################################################################


##Anova Test Model##
ols  = ols("Score ~ (Teaching_Method) + (Prior_Knowledge)", data = df).fit()
print(ols.summary())

###Plot Residuals###
##Check For Normality Assumption##

#Get Residuals#

ols_resid = ols.resid

#Plot Residuals qqplot#

fig = plt.figure(figsize= (10, 10))
ax = fig.add_subplot(111)

normality_plot, stat = stats.probplot(ols_resid, plot=plt, rvalue=True)
ax.set_title("Probability Plot of Model Residuals", fontsize=20)
ax.set

plt.show()

#Print Normality test(Shapiro test)#

print(stats.shapiro(ols_resid))

### Assessing Constant Variance ###

## Obtain Standardized Residuals ##

standardized_residuals = ols.get_influence().resid_studentized_internal

## Get the fitted values ##

fitted_values = ols.fittedvalues

## Create the plot ##

plt.figure(figsize=(8, 6))
plt.scatter(fitted_values, standardized_residuals)
plt.axhline(y=0, linestyle='dashed', color='red')
plt.axhline(y=3, color='blue')
plt.axhline(y=-3, color='blue')
plt.xlabel("Predicted y's")
plt.ylabel("Standardized Residuals")
plt.title("Standardized Residuals vs. Fitted Values")
plt.style.use('classic')
plt.show()

## B-P Test ##

## Import necessary function: ##

from statsmodels.stats.diagnostic import het_breuschpagan

## Run B-P Test ##

bp_test = het_breuschpagan(ols.resid,ols.model.exog)

## Extract F-statistic ##

f_statistic = bp_test[2]

## Extract its P-Value ##

f_p_value = bp_test[3]

print(f"F-statistic: {f_statistic}")
print(f"F p-value: {f_p_value}")

###Perform Tukey's HSD post-hoc Test###
tukey_result = pairwise_tukeyhsd(df["Score"], df["Teaching_Method"])
print(tukey_result)
# Out:
#                     mean       std  count
# Teaching_Method
# Collaborative    86.5515  9.047417     20
# Direct           75.3285  6.441470     20
# Inquiry          85.2635  6.499371     20
#                             OLS Regression Results
# ...
# Dep. Variable:                  Score   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     15.32
# Date:                Thu, 25 Sep 2025   Prob (F-statistic):           2.14e-07
# Time:                        03:31:42   Log-Likelihood:                -197.70
# No. Observations:                  60   AIC:                             403.4
# Df Residuals:                      56   BIC:                             411.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...
